# %%
import pandas as pd

# %%
df = pd.read_csv('TWT49U-new.csv', encoding='utf8', skiprows=1)

# %%
df = df[:-12]

# %%
df[df['股票代號'] == '0050']
# Out:
#               資料日期  股票代號    股票名稱 除權息前收盤價  除權息參考價  權值+息值 權/息    漲停價格   跌停價格  \
# 987      94年05月19日  0050  元大台灣50   46.69   44.84   1.85   息   47.97  41.71
# 2034     95年10月26日  0050  元大台灣50    57.4    53.4   4.00   息    57.1  49.67
# 2570     96年10月24日  0050  元大台灣50    70.6    68.1   2.50   息   72.85  63.35
# 3185     97年10月24日  0050  元大台灣50   35.51   33.51   2.00   息   35.85  32.34
# 3678     98年10月23日  0050  元大台灣50    53.7    52.7   1.00   息   56.35  49.02
# 4306     99年10月25日  0050  元大台灣50    57.1    54.9   2.20   息    58.7   51.1
# 5034   0100年10月26日  0050  元大台灣50    53.6   51.65   1.95   息   55.25  48.04
# 5704   0101年10月24日  0050  元大台灣50    52.9   51.05   1.85   息    54.6  47.48
# 6390   0102年10月24日  0050  元大台灣50    58.7   57.35   1.35   息   61.35  53.35
# 7134   0103年10月24日  0050  元大台灣50   65.05    63.5   1.55   息    67.9   59.1
# 7875   0104年10月26日  0050  元大台灣50    65.9    63.9   2.00   息   70.25  57.55
# ...

# %%
df50 = df[df['股票代號'] == '0050']

# %%
df50.to_csv('0050.csv', encoding='utf8', index=False, header=True)

# %%
df50.set_index('資料日期')
# Out:
#              股票代號    股票名稱 除權息前收盤價  除權息參考價  權值+息值 權/息    漲停價格   跌停價格  開盤競價基準  \
# 資料日期
# 94年05月19日    0050  元大台灣50   46.69   44.84   1.85   息   47.97  41.71   44.84
# 95年10月26日    0050  元大台灣50    57.4    53.4   4.00   息    57.1  49.67    53.4
# 96年10月24日    0050  元大台灣50    70.6    68.1   2.50   息   72.85  63.35    68.1
# 97年10月24日    0050  元大台灣50   35.51   33.51   2.00   息   35.85  32.34   33.51
# 98年10月23日    0050  元大台灣50    53.7    52.7   1.00   息   56.35  49.02    52.7
# 99年10月25日    0050  元大台灣50    57.1    54.9   2.20   息    58.7   51.1    54.9
# 0100年10月26日  0050  元大台灣50    53.6   51.65   1.95   息   55.25  48.04   51.65
# 0101年10月24日  0050  元大台灣50    52.9   51.05   1.85   息    54.6  47.48   51.05
# 0102年10月24日  0050  元大台灣50    58.7   57.35   1.35   息   61.35  53.35   57.35
# 0103年10月24日  0050  元大台灣50   65.05    63.5   1.55   息    67.9   59.1    63.5
# 0104年10月26日  0050  元大台灣50    65.9    63.9   2.00   息   70.25  57.55    63.9
# ...

# %%
def convert_date(data):
    tmp = data['資料日期'].replace('年', '/').replace('月', '/').replace('日', '/')
    _tmp = tmp.split('/')
    return f"{int(_tmp[0]) + 1911}{_tmp[1]}{_tmp[2]}"

# %%
df50['資料日期'] = df50.apply(convert_date, axis=1)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df50 = df50.set_index('資料日期')

# %%
df50_dict = df50.to_dict('index')

# %%
with open("0050ExDividend.json", "w") as outfile: 
    json.dump(df50_dict, outfile)
